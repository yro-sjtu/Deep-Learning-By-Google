# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'originated', 'a', 'as', 'of', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.070945
# Nearest to for: monsignor, daemen, bruins, dream, arbuthnot, meredith, between, hurling,
# Nearest to states: walras, components, nazarbayev, anglian, jass, const, lithuania, pumpkin,
# Nearest to no: bandleaders, delany, farr, sustainability, cistercian, fishermen, depending, fortress,
# Nearest to many: unfair, apologize, stairs, hectic, paigc, strings, paedophilia, puzzle,
# Nearest to that: straightforward, ecumenical, ottoman, judged, suffrage, donated, maiden, remini,
# Nearest to often: dactyl, annealing, ima, flees, khalq, ligase, amazonas, specification,
# Nearest to his: quarry, ghidorah, cults, habitat, ably, hippie, nagano, harmonicas,
# Nearest to its: bryozoans, cheated, lia, yellow, necklaces, abrasion, coma, undertaking,
# Nearest to s: registrations, strikeout, traditionalist, dravidians, kepler, axes, schottenheimer, further,
# Nearest to there: answered, gustavus, class, combating, mambo, sunk, helmet, expressionism,
# Nearest to up: granting, paleontologist, plekhanov, su, constituent, barbara, swapping, advertisers,
# Nearest to seven: sz, djibouti, remain, metastable, neil, adopting, landlord, agouti,
# Nearest to is: santorum, hermon, migrate, declarations, ambrose, gravitation, wcw, samples,
# Nearest to between: elizabeth, euphonium, peep, permissions, awm, unshielded, for, organist,
# Nearest to use: fables, jeong, picnic, secretory, ois, towering, adversarial, ethertype,
# Nearest to world: bayezid, medlineplus, lasor, organometallic, preferential, jaroslav, azzam, dienes,
# Average loss at step 2000: 4.378957
# Average loss at step 4000: 3.867437
# Average loss at step 6000: 3.790516
# Average loss at step 8000: 3.686500
# Average loss at step 10000: 3.620086
# Nearest to for: blackstone, in, wollstonecraft, of, with, meredith, ncia, during,
# Nearest to states: nazarbayev, anglian, walras, components, repeater, army, jass, embarking,
# Nearest to no: sustainability, hand, developments, melding, comedienne, bothwell, bandleaders, mestre,
# Nearest to many: some, motte, contrived, paigc, relates, stuffed, unfair, paedophilia,
# Nearest to that: which, this, supervisor, inlaid, toss, beehive, it, opaque,
# Nearest to often: monotheism, dactyl, taxicab, who, bartleby, compactly, also, tischendorf,
# Nearest to his: their, the, her, its, s, tennis, this, kocher,
# Nearest to its: their, his, the, cheated, abrasion, yellow, cheerfully, bryozoans,
# Nearest to s: his, website, widow, kepler, dolmens, kendall, asser, jain,
# Nearest to there: it, they, he, answered, cher, expressionism, today, helmet,
# Nearest to up: constituent, granting, irwin, chosen, barbara, rightarrow, parrots, womanhood,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to is: was, are, has, be, olin, became, wastes, andries,
# Nearest to between: of, euphonium, elizabeth, since, from, racks, arminius, otago,
# Nearest to use: fables, fronted, entebbe, refrigerant, ois, metalwork, adversarial, admittedly,
# Nearest to world: necked, meters, joked, portion, snowmobiles, bayezid, low, reasoner,
# Average loss at step 12000: 3.606117
# Average loss at step 14000: 3.567599
# Average loss at step 16000: 3.411142
# Average loss at step 18000: 3.460002
# Average loss at step 20000: 3.542009
# Nearest to for: of, in, during, by, referenced, with, or, as,
# Nearest to states: nazarbayev, components, army, anglian, jass, punishing, legionnaires, walras,
# Nearest to no: developments, comedienne, hand, udma, it, sustainability, leprosy, kurds,
# Nearest to many: some, several, these, other, all, stuffed, paigc, such,
# Nearest to that: which, but, supervisor, what, this, however, calculators, also,
# Nearest to often: also, usually, who, sometimes, widely, generally, now, dactyl,
# Nearest to his: their, her, its, the, this, choreography, kocher, mackaye,
# Nearest to its: their, his, the, abrasion, cheated, bryozoans, some, cfr,
# Nearest to s: discord, kendall, website, triples, provides, axes, refresh, sula,
# Nearest to there: they, it, he, which, we, answered, today, still,
# Nearest to up: chosen, out, irwin, them, marvels, constituent, operatives, adiabatic,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to is: was, has, are, be, does, were, but, bliss,
# Nearest to between: with, euphonium, arminius, in, cde, otago, helix, from,
# Nearest to use: metalwork, negated, shameless, soured, fronted, adversarial, methylene, refrigerant,
# Nearest to world: necked, portion, meters, snowmobiles, gamsakhurdia, bayezid, joked, lager,
# Average loss at step 22000: 3.498270
# Average loss at step 24000: 3.487893
# Average loss at step 26000: 3.481187
# Average loss at step 28000: 3.478728
# Average loss at step 30000: 3.505370
# Nearest to for: blackstone, with, justices, while, of, kroto, topology, ncia,
# Nearest to states: nazarbayev, barons, components, anglian, army, us, jass, banyan,
# Nearest to no: developments, they, hand, comedienne, generally, delany, leprosy, bothwell,
# Nearest to many: some, several, these, all, paigc, petroleum, such, most,
# Nearest to that: which, however, what, but, this, golfo, opaque, because,
# Nearest to often: usually, sometimes, commonly, generally, also, widely, now, still,
# Nearest to his: her, their, its, the, s, my, mackaye, ably,
# Nearest to its: their, his, the, bryozoans, selectable, abrasion, some, ystok,
# Nearest to s: his, kendall, discord, her, guarani, disengagement, iphigenia, roadways,
# Nearest to there: they, it, he, we, still, now, today, combating,
# Nearest to up: them, out, chosen, away, constituent, granting, marvels, sportscaster,
# Nearest to seven: eight, nine, six, four, five, three, zero, two,
# Nearest to is: was, has, are, does, became, when, had, while,
# Nearest to between: with, arminius, from, euphonium, otago, in, since, cde,
# Nearest to use: methylene, stuffed, negated, metalwork, carpets, misalignment, immigration, shameless,
# Nearest to world: necked, portion, snowmobiles, lager, adaptable, crowd, meters, joked,
# Average loss at step 32000: 3.501024
# Average loss at step 34000: 3.498397
# Average loss at step 36000: 3.453583
# Average loss at step 38000: 3.298605
# Average loss at step 40000: 3.429000
# Nearest to for: from, of, in, blackstone, if, using, meredith, by,
# Nearest to states: kingdom, nazarbayev, us, anglian, finalists, banyan, nations, components,
# Nearest to no: developments, generally, boiling, often, bothwell, any, delany, now,
# Nearest to many: some, several, these, petroleum, all, those, most, stuffed,
# Nearest to that: which, this, what, however, identification, who, supervisor, because,
# Nearest to often: usually, sometimes, generally, commonly, widely, also, typically, frequently,
# Nearest to his: her, their, its, the, my, him, s, ably,
# Nearest to its: their, his, the, her, selectable, considerations, disks, whose,
# Nearest to s: her, his, kendall, mountbatten, pashtun, anac, skaro, shao,
# Nearest to there: they, it, he, still, we, she, usually, now,
# Nearest to up: out, them, chosen, away, him, granting, back, lakers,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to is: was, has, does, became, are, be, if, contains,
# Nearest to between: from, with, in, since, befriends, arminius, otago, euphonium,
# Nearest to use: methylene, amour, carpets, negated, marco, misalignment, immigration, macrovision,
# Nearest to world: joked, meters, necked, portion, workplace, unborn, crowd, aral,
# Average loss at step 42000: 3.436753
# Average loss at step 44000: 3.452467
# Average loss at step 46000: 3.452612
# Average loss at step 48000: 3.351616
# Average loss at step 50000: 3.381385
# Nearest to for: while, including, blackstone, during, by, tsiolkovsky, meredith, groove,
# Nearest to states: kingdom, nazarbayev, nations, banyan, anglian, legionnaires, mtu, barons,
# Nearest to no: any, a, developments, less, ruhollah, only, delany, comedienne,
# Nearest to many: some, several, these, such, various, those, most, artistry,
# Nearest to that: which, however, this, what, because, where, bully, ottoman,
# Nearest to often: usually, sometimes, commonly, generally, widely, now, frequently, typically,
# Nearest to his: their, her, its, my, the, your, carmine, our,
# Nearest to its: their, his, the, her, whose, our, considerations, disks,
# Nearest to s: merchants, whose, aneurin, axes, savoury, powerless, discord, elaborating,
# Nearest to there: they, it, he, she, today, now, who, still,
# Nearest to up: out, them, away, chosen, back, him, lakers, chronica,
# Nearest to seven: eight, six, nine, four, five, three, two, zero,
# Nearest to is: was, has, are, became, contains, although, does, be,
# Nearest to between: with, within, against, in, arminius, from, since, across,
# Nearest to use: lack, methylene, carpets, end, drop, stuffed, interest, misalignment,
# Nearest to world: meters, joked, necked, lasor, gamsakhurdia, workplace, decoction, stage,
# Average loss at step 52000: 3.436921
# Average loss at step 54000: 3.426223
# Average loss at step 56000: 3.440621
# Average loss at step 58000: 3.394684
# Average loss at step 60000: 3.392955
# Nearest to for: of, when, including, if, in, without, blackstone, bosporus,
# Nearest to states: kingdom, nations, nazarbayev, barons, state, finalists, witnesses, hands,
# Nearest to no: any, ruhollah, comedienne, knighted, umlauts, less, only, obligate,
# Nearest to many: some, several, these, various, such, all, most, both,
# Nearest to that: which, what, this, however, oppositions, why, because, it,
# Nearest to often: usually, sometimes, commonly, generally, now, frequently, typically, widely,
# Nearest to his: her, their, its, my, our, the, your, ably,
# Nearest to its: their, his, the, her, our, whose, thunder, aspired,
# Nearest to s: kendall, shao, recessive, irreconcilable, aneurin, whose, stine, hadn,
# Nearest to there: they, it, he, today, she, this, now, still,
# Nearest to up: out, them, away, him, back, chosen, down, lakers,
# Nearest to seven: six, five, eight, four, nine, three, zero, one,
# Nearest to is: was, are, has, be, although, became, remains, contains,
# Nearest to between: with, within, arminius, since, befriends, from, against, serpentine,
# Nearest to use: usage, methylene, lack, benetton, call, negated, purine, misalignment,
# Nearest to world: joked, meters, crowd, necked, neighbouring, decoction, lasor, stage,
# Average loss at step 62000: 3.238449
# Average loss at step 64000: 3.253072
# Average loss at step 66000: 3.406078
# Average loss at step 68000: 3.392703
# Average loss at step 70000: 3.361797
# Nearest to for: if, in, including, topology, quadratic, while, blackstone, without,
# Nearest to states: kingdom, nations, nazarbayev, state, hands, barons, countries, banyan,
# Nearest to no: any, less, comedienne, generally, than, everyone, obligate, umlauts,
# Nearest to many: some, several, these, all, various, such, most, few,
# Nearest to that: which, what, however, where, but, gnosis, this, ionic,
# Nearest to often: usually, sometimes, commonly, generally, now, frequently, typically, widely,
# Nearest to his: her, their, its, my, our, your, mackaye, roundabout,
# Nearest to its: their, his, the, her, our, whose, bryozoans, conservatoire,
# Nearest to s: whose, kendall, recessive, announcements, aneurin, subtree, sula, schechter,
# Nearest to there: they, it, he, still, she, now, we, today,
# Nearest to up: out, them, away, down, back, off, him, lakers,
# Nearest to seven: eight, six, four, nine, five, three, two, one,
# Nearest to is: was, has, are, be, although, plutonium, became, does,
# Nearest to between: with, within, among, arminius, in, serpentine, from, carew,
# Nearest to use: lack, most, usage, call, allow, way, quotations, stuffed,
# Nearest to world: meters, stage, karelian, joked, crowd, dahomey, megaliths, gamsakhurdia,
# Average loss at step 72000: 3.372604
# Average loss at step 74000: 3.344005
# Average loss at step 76000: 3.310980
# Average loss at step 78000: 3.350471
# Average loss at step 80000: 3.379142
# Nearest to for: mahjong, quadratic, pretoria, including, blackstone, bosporus, if, inverse,
# Nearest to states: kingdom, nations, state, nazarbayev, legionnaires, us, countries, barons,
# Nearest to no: any, obligate, everyone, little, comedienne, delany, moonlight, subjecting,
# Nearest to many: some, several, various, these, all, most, those, both,
# Nearest to that: which, however, where, what, ayres, why, nejd, opaque,
# Nearest to often: sometimes, usually, commonly, generally, frequently, typically, now, widely,
# Nearest to his: her, their, its, my, your, our, the, daw,
# Nearest to its: their, his, her, the, our, whose, your, selectable,
# Nearest to s: holbein, recessive, guatemalans, disengagement, her, shao, whose, canaria,
# Nearest to there: it, they, he, she, still, we, now, often,
# Nearest to up: out, them, off, away, down, back, him, chosen,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to is: was, has, are, although, remains, became, becomes, be,
# Nearest to between: with, among, within, arminius, against, befriends, across, molten,
# Nearest to use: because, methylene, lack, way, amour, predict, fluctuations, mention,
# Nearest to world: karelian, meters, stage, crowd, joked, lasor, resurfaced, woodruff,
# Average loss at step 82000: 3.404588
# Average loss at step 84000: 3.405562
# Average loss at step 86000: 3.392950
# Average loss at step 88000: 3.354971
# Average loss at step 90000: 3.364452
# Nearest to for: of, including, without, after, supersede, against, therus, while,
# Nearest to states: kingdom, nations, state, barons, us, elections, governments, agencies,
# Nearest to no: any, only, little, than, everyone, obligate, generally, less,
# Nearest to many: some, several, these, all, various, those, numerous, most,
# Nearest to that: which, however, why, what, but, where, opaque, ayres,
# Nearest to often: sometimes, commonly, usually, frequently, generally, typically, now, also,
# Nearest to his: her, their, its, my, your, our, s, the,
# Nearest to its: their, his, her, the, our, your, whose, selectable,
# Nearest to s: his, aneurin, whose, holbein, calibers, sula, guatemalans, skimmed,
# Nearest to there: they, it, he, she, still, we, now, exchanges,
# Nearest to up: out, off, away, them, down, back, him, bias,
# Nearest to seven: eight, six, four, five, nine, three, one, zero,
# Nearest to is: was, has, are, be, although, became, contains, requires,
# Nearest to between: with, within, among, arminius, against, across, carew, through,
# Nearest to use: methylene, usage, allow, support, migration, sectarianism, list, way,
# Nearest to world: karelian, stage, neural, objectivist, workplace, scylla, movement, meters,
# Average loss at step 92000: 3.394416
# Average loss at step 94000: 3.256192
# Average loss at step 96000: 3.358292
# Average loss at step 98000: 3.245732
# Average loss at step 100000: 3.354028
# Nearest to for: when, if, without, including, while, against, blackstone, lamarr,
# Nearest to states: kingdom, nations, us, elections, countries, agencies, barons, state,
# Nearest to no: any, only, little, generally, everyone, traditionally, less, moonlight,
# Nearest to many: some, several, various, these, numerous, all, those, few,
# Nearest to that: which, what, however, nejd, why, where, barthes, because,
# Nearest to often: sometimes, commonly, usually, generally, frequently, typically, now, widely,
# Nearest to his: her, their, my, its, your, our, the, s,
# Nearest to its: their, his, our, her, the, whose, thunder, selectable,
# Nearest to s: whose, his, savoury, kendall, her, aneurin, my, sula,
# Nearest to there: they, he, it, we, now, she, often, still,
# Nearest to up: out, off, them, down, back, away, him, nasalized,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to is: was, has, became, are, som, be, contains, remains,
# Nearest to between: with, within, among, arminius, against, across, from, carew,
# Nearest to use: support, allow, usage, sense, methylene, flaw, fluctuations, predict,
# Nearest to world: karelian, stage, meters, workplace, vulgar, neural, scylla, largest,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
