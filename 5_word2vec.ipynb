# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'term', 'anarchism', 'term', 'originated', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
import time
start_time = time.time()

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, _loss = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += _loss
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
# # google's code    
#       for i in range(valid_size):
#         valid_word = reverse_dictionary[valid_examples[i]]
#         top_k = 8 # number of nearest neighbors
#         nearest = (-sim[i, :]).argsort()[1:top_k+1]
#         log = 'Nearest to %s:' % valid_word
#         for k in range(top_k):
#           close_word = reverse_dictionary[nearest[k]]
#           log = '%s %s,' % (log, close_word)
#         print(log)

      # my simplified code
      top_k = 8
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        close_words = [reverse_dictionary[j] for j in nearest]
        log = "Nearest to %s: %s" % (valid_word, ", ".join(close_words))
        print (log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.598250
# Nearest to first: logographic, bartolommeo, overload, unaccompanied, yf, exchanger, contralto, sticky
# Nearest to zero: ceylon, duodecimal, reciprocating, bedford, muons, amplified, outcasts, sumatra
# Nearest to no: liter, jarre, gillies, shallow, hitter, eugenic, lockport, tropes
# Nearest to from: narayana, beatles, steppe, struck, tartan, enduring, speciality, maintainers
# Nearest to nine: frankie, causal, bowen, petite, yeah, resurgent, jamo, galen
# Nearest to or: exquisite, spada, gall, islamism, posterity, diplomats, troglodytes, fumes
# Nearest to seven: skopje, load, grunwald, mascot, gas, javier, ties, mikhailovich
# Nearest to that: putsch, catalysed, shays, dewey, ctrl, compiler, martyrs, pronouncing
# Nearest to system: heliopause, decree, mauss, panini, blue, egyptian, palladius, diphthongs
# Nearest to only: factorizations, men, caledonian, resumes, wounding, cyberspace, hus, wadsworth
# Nearest to is: bartos, chondrites, luxuriant, vladislav, septic, undertakes, infants, digimon
# Nearest to been: ruthenian, hutterites, transformations, desktops, bust, assays, coined, sort
# Nearest to use: aluminum, fated, spr, suction, herring, disagreements, interacting, rapture
# Nearest to world: canaveral, ornament, connector, righteous, amen, incunabula, kernel, spoil
# Nearest to th: tamers, management, biomass, refund, fmd, bits, layla, predictions
# Nearest to so: predict, spat, dice, cabo, marseilles, dobbs, sugar, menial
# Average loss at step 2000: 4.362994
# Average loss at step 4000: 3.864788
# Average loss at step 6000: 3.789312
# Average loss at step 8000: 3.689840
# Average loss at step 10000: 3.616084
# Nearest to first: phonetic, moussa, slip, irregularly, bartolommeo, bernstein, yf, heisenberg
# Nearest to zero: nine, five, eight, seven, six, four, three, two
# Nearest to no: it, clos, sociopathic, lockport, liberian, tropes, shakespearean, ding
# Nearest to from: on, in, into, during, keith, between, revolved, wire
# Nearest to nine: eight, seven, six, zero, five, three, four, two
# Nearest to or: and, whois, of, headed, isa, stanza, than, discrimination
# Nearest to seven: eight, six, five, nine, four, three, zero, two
# Nearest to that: which, it, sensibilities, ilyich, this, i, doreen, approves
# Nearest to system: systems, mauss, bevel, halle, heliopause, rolled, definition, subterfuge
# Nearest to only: factorizations, resumes, merina, trainees, men, pow, aeronautics, htm
# Nearest to is: was, are, has, transliterated, be, being, were, ethno
# Nearest to been: how, niccol, nonaggression, were, firmly, hutterites, mesmer, also
# Nearest to use: spr, fated, aluminum, disagreements, expansionism, herring, sgt, associating
# Nearest to world: hippocratic, horizontal, amen, washing, oubangui, tris, hyper, necessarily
# Nearest to th: tamers, shave, slapstick, layla, whisper, oxidase, pessimistic, slams
# Nearest to so: proline, predict, keepers, imperceptible, sla, meanings, comedians, lemons
# Average loss at step 12000: 3.606168
# Average loss at step 14000: 3.569596
# Average loss at step 16000: 3.406614
# Average loss at step 18000: 3.459655
# Average loss at step 20000: 3.540078
# Nearest to first: phonetic, moussa, second, slip, uffizi, across, original, bartolommeo
# Nearest to zero: five, six, eight, seven, four, three, nine, two
# Nearest to no: jointly, tirthankaras, sociopathic, lockport, ingested, a, ding, bmj
# Nearest to from: into, in, during, at, and, between, on, revolved
# Nearest to nine: eight, seven, six, five, four, zero, three, two
# Nearest to or: and, than, nepotism, should, millimetres, gillian, for, deem
# Nearest to seven: eight, six, nine, four, five, three, zero, two
# Nearest to that: which, but, shays, hipper, doreen, what, this, qing
# Nearest to system: systems, mauss, definition, mantras, bevel, egyptian, instruments, heliopause
# Nearest to only: factorizations, wpm, buddhas, it, resumes, steiger, aeronautics, carey
# Nearest to is: was, has, are, be, were, but, by, finger
# Nearest to been: be, become, were, was, never, nonaggression, already, hashem
# Nearest to use: spr, antibiotic, sgt, expansionism, disagreements, aluminum, place, yousef
# Nearest to world: hippocratic, massed, hyper, chefs, koine, tending, hegelian, canaveral
# Nearest to th: whisper, slapstick, pessimistic, inapplicable, shave, mens, slams, pervasive
# Nearest to so: too, imperceptible, keepers, proline, she, predict, sla, decentralization
# Average loss at step 22000: 3.498227
# Average loss at step 24000: 3.493551
# Average loss at step 26000: 3.481812
# Average loss at step 28000: 3.481198
# Average loss at step 30000: 3.500426
# Nearest to first: last, second, phonetic, third, next, original, same, moussa
# Nearest to zero: five, eight, four, seven, nine, three, six, two
# Nearest to no: a, jointly, any, ingested, eritrean, there, ding, lockport
# Nearest to from: into, during, in, on, revolved, of, motherboards, between
# Nearest to nine: eight, seven, six, five, four, three, zero, two
# Nearest to or: and, aquarius, etat, frowned, nepotism, wild, floating, aeronautical
# Nearest to seven: eight, five, nine, six, four, three, zero, one
# Nearest to that: which, but, however, this, what, qing, doreen, shays
# Nearest to system: systems, mantras, mauss, definition, scholasticus, snub, heliopause, instruments
# Nearest to only: meticulous, rs, it, this, wpm, resumes, sporting, justin
# Nearest to is: was, has, are, be, had, does, were, became
# Nearest to been: become, be, was, already, were, never, had, always
# Nearest to use: antibiotic, exothermic, spr, popularize, most, coated, devon, aluminum
# Nearest to world: hippocratic, madhava, hegelian, koine, breakers, chefs, calico, grapevines
# Nearest to th: bc, six, slapstick, rd, whisper, eight, lair, pessimistic
# Nearest to so: too, imperceptible, decentralization, shreck, wraith, keepers, jericho, sla
# Average loss at step 32000: 3.505796
# Average loss at step 34000: 3.492078
# Average loss at step 36000: 3.459643
# Average loss at step 38000: 3.301201
# Average loss at step 40000: 3.432151
# Nearest to first: second, last, next, third, phonetic, final, moussa, uffizi
# Nearest to zero: seven, eight, nine, five, six, three, four, two
# Nearest to no: any, jointly, damnation, ingested, lockport, toon, eritrean, tirthankaras
# Nearest to from: into, during, between, in, through, incestuous, nster, with
# Nearest to nine: eight, seven, six, five, four, zero, three, one
# Nearest to or: and, than, nepotism, the, climactic, zanu, no, wishful
# Nearest to seven: eight, six, nine, five, four, three, zero, two
# Nearest to that: which, what, this, however, qing, if, who, ilyich
# Nearest to system: systems, definition, instruments, mauss, mantras, trask, monaro, defector
# Nearest to only: meticulous, wpm, emphases, rs, suicide, putative, sulpicius, steiger
# Nearest to is: was, has, are, if, be, equivalents, cider, transliterated
# Nearest to been: become, be, was, already, had, were, never, always
# Nearest to use: antibiotic, unprofessional, exothermic, devon, most, gia, counterattacks, teil
# Nearest to world: koine, spears, hegelian, calico, layout, hippocratic, excretory, breakers
# Nearest to th: eight, bc, rd, five, slapstick, whisper, three, nd
# Nearest to so: too, decentralization, imperceptible, jericho, less, proline, calicut, shreck
# Average loss at step 42000: 3.434023
# Average loss at step 44000: 3.451013
# Average loss at step 46000: 3.449528
# Average loss at step 48000: 3.357513
# Average loss at step 50000: 3.383779
# Nearest to first: second, last, final, third, phonetic, next, moussa, during
# Nearest to zero: five, seven, nine, eight, four, six, three, two
# Nearest to no: any, jointly, eritrean, damnation, breatharian, little, foreshadowed, toon
# Nearest to from: into, through, during, in, revolved, between, nster, after
# Nearest to nine: eight, seven, six, four, five, three, zero, one
# Nearest to or: and, than, nepotism, provincial, characterizing, tatra, heighten, hardens
# Nearest to seven: six, nine, eight, four, five, three, zero, one
# Nearest to that: which, what, however, gauntlets, who, ilyich, shays, putsch
# Nearest to system: systems, instruments, definition, parsley, ethic, trask, mauss, mantras
# Nearest to only: usually, meticulous, last, wounding, still, steiger, compaor, bypassed
# Nearest to is: was, are, has, became, were, be, includes, hotline
# Nearest to been: become, be, was, already, were, had, begun, blockading
# Nearest to use: most, change, teil, unprofessional, antibiotic, foreseeable, counterattacks, denial
# Nearest to world: heartbeat, slobodan, hegelian, koine, calico, spears, breakers, layout
# Nearest to th: bc, rd, eight, slapstick, six, nd, one, predication
# Nearest to so: too, decentralization, then, galleria, imperceptible, mendel, sla, costanza
# Average loss at step 52000: 3.436507
# Average loss at step 54000: 3.432465
# Average loss at step 56000: 3.438509
# Average loss at step 58000: 3.398469
# Average loss at step 60000: 3.392796
# Nearest to first: last, second, next, third, final, finally, outback, originally
# Nearest to zero: five, four, seven, eight, nine, six, three, two
# Nearest to no: any, jointly, damnation, little, eritrean, excitotoxins, breatharian, ingested
# Nearest to from: into, through, revolved, during, in, between, after, and
# Nearest to nine: eight, six, seven, four, five, zero, three, one
# Nearest to or: and, than, heighten, mathematische, nepotism, millimetres, flirty, predicting
# Nearest to seven: eight, six, five, four, nine, three, zero, two
# Nearest to that: which, what, this, however, where, it, doreen, retroviruses
# Nearest to system: systems, definition, mauss, instruments, phenomenon, union, program, clotting
# Nearest to only: usually, last, until, meticulous, still, first, always, no
# Nearest to is: was, are, has, attendances, becomes, became, includes, cider
# Nearest to been: become, be, already, had, was, begun, were, historically
# Nearest to use: most, teil, denial, cause, antibiotic, devon, sense, change
# Nearest to world: hegelian, layout, breakers, koine, hippocratic, slobodan, vietnam, thumbs
# Nearest to th: rd, bc, four, slapstick, nd, six, eight, five
# Nearest to so: too, if, rune, decentralization, less, topical, enough, spies
# Average loss at step 62000: 3.239416
# Average loss at step 64000: 3.258425
# Average loss at step 66000: 3.406993
# Average loss at step 68000: 3.395822
# Average loss at step 70000: 3.358559
# Nearest to first: second, last, third, next, same, final, uffizi, best
# Nearest to zero: five, eight, four, six, nine, seven, three, two
# Nearest to no: any, little, jointly, breatharian, actually, damnation, eritrean, only
# Nearest to from: into, through, during, revolved, between, graciously, under, standardised
# Nearest to nine: eight, six, seven, five, four, zero, three, one
# Nearest to or: and, than, mathematische, nepotism, haaretz, while, akkadian, reprinted
# Nearest to seven: six, eight, four, nine, five, three, zero, two
# Nearest to that: which, however, this, but, what, where, luncheon, retroviruses
# Nearest to system: systems, definition, phenomenon, defector, instruments, ethic, universal, snub
# Nearest to only: usually, last, always, still, underline, no, schuler, yucat
# Nearest to is: was, has, are, became, be, does, becomes, seems
# Nearest to been: become, be, already, begun, remained, historically, were, grown
# Nearest to use: teil, most, denial, cause, return, sense, entrance, task
# Nearest to world: hegelian, breakers, koine, attrition, centennial, layout, vietnam, mapmaking
# Nearest to th: rd, bc, bce, six, slapstick, nd, bujold, eight
# Nearest to so: too, rune, decentralization, sla, costanza, saracens, topical, earth
# Average loss at step 72000: 3.372585
# Average loss at step 74000: 3.344181
# Average loss at step 76000: 3.321255
# Average loss at step 78000: 3.353498
# Average loss at step 80000: 3.377305
# Nearest to first: last, second, third, next, final, uffizi, same, best
# Nearest to zero: seven, five, eight, six, nine, four, three, two
# Nearest to no: little, any, inti, jointly, tirthankaras, breatharian, ingested, actually
# Nearest to from: through, into, during, after, revolved, ammo, between, struck
# Nearest to nine: eight, seven, five, six, four, three, zero, two
# Nearest to or: and, than, climactic, but, mathematische, trouv, peroxides, while
# Nearest to seven: six, eight, five, four, nine, three, zero, two
# Nearest to that: which, however, what, this, retroviruses, where, gauntlets, cavett
# Nearest to system: systems, program, ethic, defector, instruments, definition, phenomenon, parsley
# Nearest to only: always, last, until, usually, still, rotations, first, yucat
# Nearest to is: was, has, are, became, includes, be, although, jeanette
# Nearest to been: become, be, already, was, were, begun, had, historically
# Nearest to use: denial, most, request, increase, teil, entrance, fishes, because
# Nearest to world: hegelian, vietnam, centennial, beria, spears, cisc, koine, layout
# Nearest to th: rd, bc, slapstick, bce, nd, whisper, bujold, five
# Nearest to so: too, sla, spies, earth, sopwith, rune, decentralization, hinges
# Average loss at step 82000: 3.409096
# Average loss at step 84000: 3.412520
# Average loss at step 86000: 3.391773
# Average loss at step 88000: 3.353678
# Average loss at step 90000: 3.365915
# Nearest to first: last, second, final, third, next, best, commission, same
# Nearest to zero: five, six, eight, seven, nine, four, three, two
# Nearest to no: any, little, actually, jointly, tirthankaras, einsteinium, breatharian, visibly
# Nearest to from: through, into, during, between, revolved, after, under, within
# Nearest to nine: eight, seven, six, five, four, zero, three, two
# Nearest to or: and, heighten, thursdays, predicting, xaf, governmental, zanu, tensors
# Nearest to seven: eight, nine, six, five, four, three, zero, one
# Nearest to that: which, however, freikorps, luncheon, berkley, retroviruses, what, where
# Nearest to system: systems, program, definition, line, likelihood, defector, model, phenomenon
# Nearest to only: always, last, achieves, still, rotations, no, we, tuscan
# Nearest to is: was, has, are, becomes, be, became, requires, seems
# Nearest to been: become, be, already, historically, begun, remained, being, had
# Nearest to use: most, because, denial, treatment, teil, support, nihilistic, list
# Nearest to world: mapmaking, hegelian, beria, vietnam, surf, brazen, ambushed, explores
# Nearest to th: rd, bc, seven, eight, four, bce, fifth, slapstick
# Nearest to so: too, earth, thus, sopwith, hinges, sla, decentralization, saracens
# Average loss at step 92000: 3.396293
# Average loss at step 94000: 3.254546
# Average loss at step 96000: 3.360613
# Average loss at step 98000: 3.247013
# Average loss at step 100000: 3.356387
# Nearest to first: last, next, second, final, third, best, fourth, uffizi
# Nearest to zero: five, four, six, eight, nine, seven, three, two
# Nearest to no: little, any, actually, inti, damnation, eritrean, jointly, only
# Nearest to from: into, through, in, revolved, during, towards, within, by
# Nearest to nine: eight, seven, six, four, five, three, zero, two
# Nearest to or: and, than, characterizing, bard, doug, while, pascha, climactic
# Nearest to seven: six, eight, nine, five, four, three, two, zero
# Nearest to that: which, however, what, retroviruses, whenever, where, whom, glutamate
# Nearest to system: systems, program, model, definition, phenomenon, humphries, defector, mantras
# Nearest to only: always, still, until, coeur, not, pepys, valid, last
# Nearest to is: was, has, be, became, are, seems, makes, becomes
# Nearest to been: become, be, already, was, begun, remained, historically, discourses
# Nearest to use: most, denial, counterattacks, sense, treatment, support, teil, introduction
# Nearest to world: excretory, centennial, explores, hegelian, hilt, brazen, mecha, mapmaking
# Nearest to th: rd, bc, fifth, nd, whisper, bce, slapstick, resolves
# Nearest to so: too, thus, sopwith, later, earth, sla, decentralization, noted

# %%
end_time = time.time()
print ("time elapsed: %d s" % ((end_time - start_time)))
# Out:
# time elapsed: 225 s

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
